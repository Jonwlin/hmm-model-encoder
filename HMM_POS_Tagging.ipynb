# %%
import pickle
import math
import sys
import os.path

# %% [markdown]
# ## Creating Word and POS Elements

# %%
class Word_POS:

    delim = "/"
    def __init__(self, data, is_training):
        if is_training:
            split = data.split(self.delim)
            self.word = "/".join(split[:-1])
            self.tag = split[-1]
        else:
            self.word = data

# %%
class DataParser:
    def __init__(self, corpus_files):

        self.train_tagged, is_train_1 = corpus_files[0]

        self.train_sentences = []

        self._parse_file(self.train_tagged, self.train_sentences, is_training=is_train_1)

    def get_training_data(self):
        return self.train_sentences

    def _parse_file(self, filename, lst, is_training):
        if not filename or not os.path.isfile(filename):
            raise Exception("File not Found")

        with open(filename, "r") as f:
            for line in f:
                line = line.strip()
                word_tag = line.split()
                word_POS = [Word_POS(data, is_training) for data in word_tag]
                lst.append(word_POS)

# %%
class K_Fold_Cross_Validation:
    def __init__(self, k, training_data):
        self.portions = []
        num_sentences = int(len(training_data) / k)
        split = []
        for i, sent in enumerate(training_data):
            split.append(sent)
            if (( i + 1 ) % num_of_sentences == 0):
                self.portions.append(split)
                split = []
        if split:
            self.portions.append(split)
    def get_datas(self, index=0):
        return self.portions[index], [portion for i, portion in enumerate(self.portions) if i != index], index+1

# %%
class HMM:
    def __init__(self, corpus_files):
        self.words_given_pos = {}
        self.pos3_given_pos2_and_pos1 = {}
        self.parser = DataParser(corpus_files)
        self.word_to_tag = {}
        self.word_tag_count = {}
        self.tag_count = {}
        self.trigrams = {}
        self.bigrams = {}
        self.tags = set()
        self.words = set()
        self.transition_backoff = {}
        self.emission_backoff = {}
        self.transition_singleton = {}
        self.emission_singleton = {}
        self.transition_one_count = {}
        self.emission_smoothed = {}
        self.num = 0

    def calculate_probabilities(self):
        self.populate_dictionaries()
        self.ProbWordGivenTag()
        self.ProbTrigramTags()
        self.BackoffProbabilities()
        self.SingletonCounts()
        self.SmoothedProbabilities()
        self._save()

    def populate_dictionaries(self):
        self.pos_tags = set()
        for sentence in self.parser.get_training_data():

            sentence.insert(0, Word_POS('$^START^$' + Word_POS.delim + '$^START^$', is_training=True ))
            sentence.insert(0, Word_POS('$^START^$' + Word_POS.delim + '$^START^$', is_training=True ))

            start_index = 2
            for i in range(start_index, len(sentence)):

                trigram_triplet = (( sentence[i - 2]).tag, (sentence[i - 1]).tag, (sentence[i]).tag )
                bigram_tuple = (( sentence[i - 2]).tag, (sentence[i - 1]).tag )
                self.trigrams[trigram_triplet] = self.trigrams.get(trigram_triplet, 0) + 1
                self.bigrams[bigram_tuple] = self.bigrams.get(bigram_tuple, 0) + 1

            for i, atom in enumerate(sentence):

                word = atom.word
                tag = atom.tag
                self.num += 1
                self.transition_backoff[tag] = self.transition_backoff.get(tag, 0) + 1
                self.emission_backoff[word] = self.emission_backoff.get(word, 0) + 1
                self.tags.add(tag)
                self.words.add(word)
                self.word_tag_count[ (word, tag) ] =  self.word_tag_count.get((word, tag), 0) + 1
                self.tag_count[ tag ] = self.tag_count.get(tag, 0) + 1
                if word not in self.word_to_tag:
                    self.word_to_tag[ word ] = set()
                self.word_to_tag[ word ].add(tag)

        print(self.bigrams)
        print(self.trigrams)

    def BackoffProbabilities(self):
        V = len(self.tags)
        print(self.num, V)
        for word in self.emission_backoff:
            self.emission_backoff[word] = float(1 + self.emission_backoff[word]) / float(self.num + V)
        for tag in self.transition_backoff:
            self.transition_backoff[tag] = float(self.transition_backoff[tag]) / float(self.num)

    def SmoothedProbabilities(self):
        start_index = 2
        for sentence in self.parser.get_training_data():
            for i in range(start_index, len(sentence)):
                trigram_triplet = ( (sentence[i - 2]).tag , (sentence[i- 1]).tag, (sentence[i]).tag)
                bigram_tuple = ( (sentence[i - 2]).tag, (sentence[i- 1]).tag )
                lamda = self.transition_singleton.get(bigram_tuple, 0) + 1
                self.transition_one_count[trigram_triplet] = math.log(float(self.trigrams[trigram_triplet] + lamda * self.transition_backoff[sentence[i].tag]) / float(self.bigrams[bigram_tuple] + lamda))

        for word, tags_set in self.word_to_tag.items():
            for tag in tags_set:
                lamda = 1 + self.emission_singleton.get(tag, 0)
                self.emission_smoothed[(word, tag)] = math.log(float(self.word_tag_count[(word, tag)] + lamda * self.emission_backoff[word]) / float(self.tag_count[tag] + lamda))
                
    def SingletonCounts(self):
        for i, tag_1 in enumerate(self.tags):
            for j, tag_2 in enumerate(self.tags):
                for k, tag_3 in enumerate(self.tags):
                    if i != j and i != k and j != k:
                        triplet = (tag_3, tag_2, tag_1)
                        if triplet in self.trigrams and self.trigrams[triplet] == 1:
                            self.transition_singleton[(tag_3, tag_2)] = self.transition_singleton.get((tag_3, tag_2), 0) + 1
        for word in self.words:
            for tag in self.tags:
                word_tag = (word, tag)
                if word_tag in self.word_tag_count and self.word_tag_count[word_tag] == 1:
                    self.emission_singleton[tag] = self.emission_singleton.get(tag, 0) + 1


    def _save(self):
        dictionaries = {"unique_tags" : self.tags, "bigram" : self.bigrams, "transmission" : self.pos3_given_pos2_and_pos1, "emission" : self.words_given_pos, "word2tag" : self.word_to_tag,
                        "transition_backoff" : self.transition_backoff, "emission_backoff" : self.emission_backoff,
                        "transition_singleton" : self.transition_singleton, "emission_singleton" : self.emission_singleton,
                        "transition_smoothed" : self.transition_one_count, "emission_smoothed" : self.emission_smoothed,
                        "tag_count" : self.tag_count, "n" : self.num}
        output = open('hmmmodel.txt', 'wb')
        pickle.dump(dictionaries, output)
        output.close()

    def ProbWordGivenTag(self):
        for word, tags_set in self.word_to_tag.items():
            for tag in tags_set:
                self.words_given_pos[(word, tag)] = math.log(float(self.word_tag_count[(word, tag)]) / float(self.tag_count[tag]))

    def ProbTrigramTags(self):
        start_index = 2
        V = len(self.tags)
        for sentence in self.parser.get_training_data():
            for i in range(start_index, len(sentence)):
                trigram_triplet = ((sentence[i- 2]).tag, (sentence[i- 1]).tag, (sentence[i]).tag)
                bigram_tuple = ((sentence[i- 2]).tag, (sentence[i- 1]).tag)
                self.pos3_given_pos2_and_pos1[trigram_triplet] = math.log(float(1 + self.trigrams[trigram_triplet]) / float(V + self.bigrams[bigram_tuple]))

# %%
filename = "./en_train_tagged.txt"
hmm = HMM([(filename, True), (filename, True), (filename, True)])
hmm.calculate_probabilities()
# Out:
# {('$^START^$', '$^START^$', 'NNP'): 1455, ('$^START^$', 'NNP', 'HYPH'): 11, ('NNP', 'HYPH', 'NNP'): 132, ('HYPH', 'NNP', ':'): 3, ('NNP', ':', 'JJ'): 5, (':', 'JJ', 'NNS'): 3, ('JJ', 'NNS', 'VBD'): 51, ('NNS', 'VBD', 'NNP'): 6, ('VBD', 'NNP', 'NNP'): 35, ('NNP', 'NNP', 'NNP'): 682, ('NNP', 'NNP', 'HYPH'): 31, ('HYPH', 'NNP', ','): 21, ('NNP', ',', 'DT'): 121, (',', 'DT', 'NN'): 262, ('DT', 'NN', 'IN'): 2315, ('NN', 'IN', 'DT'): 2057, ('IN', 'DT', 'NN'): 3472, ('NN', 'IN', 'NNP'): 888, ('IN', 'NNP', ','): 356, ('NNP', ',', 'IN'): 73, (',', 'IN', 'DT'): 168, ('IN', 'DT', 'JJ'): 1245, ('DT', 'JJ', 'NN'): 2218, ('JJ', 'NN', '.'): 747, ('$^START^$', '$^START^$', '-LRB-'): 137, ('$^START^$', '-LRB-', 'DT'): 18, ('-LRB-', 'DT', 'NN'): 28, ('JJ', 'NN', 'MD'): 67, ('NN', 'MD', 'VB'): 332, ('MD', 'VB', 'VBG'): 82, ('VB', 'VBG', 'PRP'): 11, ('VBG', 'PRP', 'NN'): 5, ('PRP', 'NN', 'IN'): 7, ('NN', 'IN', 'NNS'): 386, ('IN', 'NNS', 'TO'): 18, ('NNS', 'TO', 'VB'): 166, ('TO', 'VB', '.'): 115, ('VB', '.', '-RRB-'): 3, ('$^START^$', 'NNP', ':'): 43, ('NNS', 'VBD', 'IN'): 32, ('VBD', 'IN', 'PRP'): 90, ('IN', 'PRP', 'VBD'): 370, ('PRP', 'VBD', 'VBN'): 157, ('VBD', 'VBN', 'RP'): 14, ('VBN', 'RP', 'CD'): 1, ('RP', 'CD', 'JJ'): 2, ('CD', 'JJ', 'NNS'): 53, ('JJ', 'NNS', 'VBG'): 30, ('NNS', 'VBG', 'IN'): 36, ('VBG', 'IN', 'NNP'): 91, ('IN', 'NNP', '.'): 356, ('$^START^$', '$^START^$', 'CD'): 406, ('$^START^$', 'CD', 'IN'): 15, ('CD', 'IN', 'PRP'): 33, ('PRP', 'VBD', 'VBG'): 117, ('VBD', 'VBG', 'VBN'): 9, ('VBG', 'VBN', 'IN'): 41, ('VBN', 'IN', 'CD'): 53, ('IN', 'CD', 'NNS'): 155, ('CD', 'NNS', 'IN'): 181, ('NNS', 'IN', 'DT'): 666, ('IN', 'DT', 'NNP'): 774, ('DT', 'NNP', 'IN'): 109, ('NNP', 'IN', 'DT'): 227, ('DT', 'NNP', '.'): 48, ('$^START^$', '$^START^$', 'DT'): 1411, ('$^START^$', 'DT', 'NNP'): 95, ('NNP', 'IN', 'NNP'): 281, ('IN', 'NNP', 'VBZ'): 91, ('NNP', 'VBZ', 'JJ'): 44, ('VBZ', 'JJ', 'IN'): 114, ('JJ', 'IN', 'DT'): 360, ('DT', 'NNP', 'NNP'): 461, ('NNP', 'NNP', ','): 427, ('NNP', ',', 'RB'): 60, (',', 'RB', 'DT'): 48, ('RB', 'DT', 'MD'): 10, ('DT', 'MD', 'VB'): 65, ('MD', 'VB', 'IN'): 283, ('VB', 'IN', 'VBG'): 30, ('IN', 'VBG', 'NNP'): 23, ('VBG', 'NNP', 'NNP'): 20, ('NNP', 'NNP', 'RB'): 50, ('NNP', 'RB', 'VB'): 5, ('RB', 'VB', 'IN'): 218, ('VB', 'IN', 'DT'): 454, ('JJ', 'NN', 'NNS'): 215, ('NN', 'NNS', 'IN'): 233, ('IN', 'DT', 'NNPS'): 68, ('DT', 'NNPS', 'NNS'): 2, ('NNPS', 'NNS', 'RB'): 1, ('NNS', 'RB', 'IN'): 70, ('RB', 'IN', 'DT'): 406, ('IN', 'DT', 'NNS'): 574, ('DT', 'NNS', '.'): 191, ('$^START^$', 'DT', 'JJ'): 244, ('DT', 'JJ', 'VBD'): 5, ('JJ', 'VBD', 'VBG'): 1, ('VBN', 'IN', 'DT'): 478, ('DT', 'NN', 'NN'): 990, ('NN', 'NN', '.'): 542, ('$^START^$', '$^START^$', 'PRP'): 2817, ('$^START^$', 'PRP', 'VBP'): 1071, ('PRP', 'VBP', 'IN'): 300, ('VBP', 'IN', 'PRP'): 81, ('VBD', 'VBG', 'DT'): 22, ('VBG', 'DT', 'NN'): 336, ('NN', 'IN', 'PRP$'): 350, ('IN', 'PRP$', 'NN'): 813, ('PRP$', 'NN', 'NNS'): 50, ('NN', 'NNS', '.'): 210, ('$^START^$', 'DT', 'NNS'): 124, ('DT', 'NNS', 'VBD'): 69, ('NNS', 'VBD', 'VBG'): 18, ('VBD', 'VBG', 'IN'): 66, ('VBG', 'IN', 'DT'): 280, ('DT', 'NNP', 'CC'): 52, ('NNP', 'CC', 'NNP'): 351, ('CC', 'NNP', 'HYPH'): 9, ('HYPH', 'NNP', 'NNS'): 6, ('NNP', 'NNS', 'IN'): 37, ('DT', 'NN', '.'): 1014, ('$^START^$', '$^START^$', 'IN'): 980, ('$^START^$', 'IN', 'DT'): 286, ('DT', 'NN', 'VBD'): 275, ('NN', 'VBD', 'RB'): 133, ('VBD', 'RB', 'VBN'): 76, ('RB', 'VBN', 'TO'): 25, ('VBN', 'TO', 'VB'): 172, ('TO', 'VB', 'NN'): 160, ('VB', 'NN', 'IN'): 144, ('NN', 'IN', 'VBG'): 193, ('IN', 'VBG', 'CC'): 9, ('VBG', 'CC', 'VBG'): 22, ('CC', 'VBG', 'RP'): 3, ('VBG', 'RP', 'NN'): 5, ('RP', 'NN', 'NNS'): 2, ('NN', 'NNS', ','): 178, ('NNS', ',', 'PRP'): 89, (',', 'PRP', 'VBP'): 278, ('PRP', 'VBP', 'RB'): 700, ('VBP', 'RB', 'VB'): 300, ('RB', 'VB', 'DT'): 309, ('VB', 'DT', 'NN'): 1012, ('DT', 'NNPS', 'VBP'): 18, ('NNPS', 'VBP', 'TO'): 3, ('VBP', 'TO', 'VB'): 288, ('TO', 'VB', 'DT'): 720, ('VB', 'DT', 'JJ'): 369, ('JJ', 'NN', 'RB'): 100, ('NN', 'RB' ...
# **************************************************
# {('$^START^$', '$^START^$'): 12543, ('$^START^$', 'NNP'): 1155, ('NNP', 'HYPH'): 170, ('HYPH', 'NNP'): 135, ('NNP', ':'): 50, (':', 'JJ'): 25, ('JJ', 'NNS'): 1782, ('NNS', 'VBD'): 264, ('VBD', 'NNP'): 148, ('NNP', 'NNP'): 3035, ('NNP', ','): 1280, (',', 'DT'): 640, ('DT', 'NN'): 8225, ('NN', 'IN'): 6007, ('IN', 'DT'): 6903, ('IN', 'NNP'): 2712, (',', 'IN'): 670, ('DT', 'JJ'): 3298, ('JJ', 'NN'): 4528, ('$^START^$', '-LRB-'): 137, ('-LRB-', 'DT'): 66, ('NN', 'MD'): 431, ('MD', 'VB'): 2306, ('VB', 'VBG'): 187, ('VBG', 'PRP'): 194, ('PRP', 'NN'): 47, ('IN', 'NNS'): 820, ('NNS', 'TO'): 174, ('TO', 'VB'): 3193, ('VB', '.'): 16, ('VBD', 'IN'): 695, ('IN', 'PRP'): 2237, ('PRP', 'VBD'): 2271, ('VBD', 'VBN'): 465, ('VBN', 'RP'): 100, ('RP', 'CD'): 7, ('CD', 'JJ'): 119, ('NNS', 'VBG'): 138, ('VBG', 'IN'): 679, ('$^START^$', 'CD'): 406, ('CD', 'IN'): 349, ('VBD', 'VBG'): 231, ('VBG', 'VBN'): 87, ('VBN', 'IN'): 1292, ('IN', 'CD'): 745, ('CD', 'NNS'): 666, ('NNS', 'IN'): 2029, ('DT', 'NNP'): 1347, ('NNP', 'IN'): 810, ('$^START^$', 'DT'): 1411, ('NNP', 'VBZ'): 592, ('VBZ', 'JJ'): 513, ('JJ', 'IN'): 1089, (',', 'RB'): 592, ('RB', 'DT'): 456, ('DT', 'MD'): 83, ('VB', 'IN'): 1397, ('IN', 'VBG'): 645, ('VBG', 'NNP'): 85, ('NNP', 'RB'): 190, ('RB', 'VB'): 1594, ('NN', 'NNS'): 1149, ('DT', 'NNPS'): 135, ('NNPS', 'NNS'): 6, ('NNS', 'RB'): 389, ('RB', 'IN'): 1253, ('DT', 'NNS'): 1358, ('JJ', 'VBD'): 17, ('NN', 'NN'): 3000, ('$^START^$', 'PRP'): 2817, ('PRP', 'VBP'): 3227, ('VBP', 'IN'): 491, ('VBG', 'DT'): 608, ('IN', 'PRP$'): 1332, ('PRP$', 'NN'): 1899, ('NNP', 'CC'): 733, ('CC', 'NNP'): 515, ('NNP', 'NNS'): 207, ('$^START^$', 'IN'): 980, ('NN', 'VBD'): 696, ('VBD', 'RB'): 771, ('RB', 'VBN'): 563, ('VBN', 'TO'): 178, ('VB', 'NN'): 411, ('VBG', 'CC'): 53, ('CC', 'VBG'): 159, ('VBG', 'RP'): 81, ('RP', 'NN'): 39, ('NNS', ','): 1002, (',', 'PRP'): 978, ('VBP', 'RB'): 1085, ('VB', 'DT'): 1870, ('NNPS', 'VBP'): 48, ('VBP', 'TO'): 294, ('NN', 'RB'): 697, ('RB', 'JJ'): 1203, ('PRP', 'VBZ'): 1067, ('VBZ', 'PRP'): 181, ('PRP', 'RB'): 791, ('RB', 'RB'): 1027, ('NNS', 'WP'): 89, ('WP', 'VBD'): 149, ('RB', 'VBG'): 303, (':', 'NNS'): 19, ('VBD', 'DT'): 894, ('PRP', 'IN'): 539, ('NNP', 'VBD'): 569, ('VBN', 'CD'): 36, ('CD', 'NN'): 627, ('IN', 'EX'): 58, ('EX', 'VBD'): 70, ('VBN', 'DT'): 324, ('NN', 'CC'): 1716, ('CC', 'PRP$'): 155, (',', 'NNP'): 741, (',', 'CD'): 157, ('PRP', 'MD'): 1792, ('VB', 'VBN'): 458, ('-LRB-', 'NNP'): 115, ('VBZ', 'IN'): 430, ('IN', 'JJ'): 1109, ('JJ', 'NNP'): 299, ('CC', 'VBZ'): 118, ('VBZ', 'DT'): 885, ('DT', 'RB'): 211, ('NN', ','): 2461, (',', 'WP'): 66, ('WP', 'VBP'): 138, ('NNS', 'CC'): 756, ('CC', 'RB'): 557, ('RB', 'VBP'): 294, ('VBP', 'PRP'): 561, ('PRP', 'RP'): 93, ('NN', 'VBZ'): 1213, ('IN', 'VBN'): 80, ('NN', 'HYPH'): 186, ('HYPH', 'NN'): 233, ('NN', '.'): 111, (',', 'JJ'): 343, (',', 'VBD'): 136, ('NNP', 'NN'): 737, ('$^START^$', 'NNS'): 186, ('RB', 'VBD'): 402, ('$^START^$', 'PRP$'): 259, ('NNS', 'VBP'): 604, ('VBP', 'VBN'): 559, ('VBN', 'VBN'): 118, ('CC', 'DT'): 704, ('NN', 'WDT'): 355, ('WDT', 'VBD'): 153, ('VBD', 'CD'): 84, ('JJ', ','): 557, (',', 'VBG'): 210, ('VBG', 'CD'): 38, ('CC', 'VBD'): 339, ('VBD', 'NN'): 149, ('CD', 'CD'): 334, ('CC', 'CD'): 89, ('PRP$', 'NNS'): 473, ('VBG', 'JJ'): 160, ('DT', 'VBZ'): 294, ('JJ', 'JJ'): 588, (',', 'CC'): 1247, ('VBN', 'JJ'): 159, ('VBZ', 'RBR'): 13, ('RBR', 'RB'): 26, ('NNP', 'CD'): 371, ('NNS', '.'): 45, (':', 'DT'): 40, ('NNP', 'TO'): 93, ('VB', 'CD'): 86, ('IN', 'NN'): 2263, ('VBN', 'RB'): 247, ('VB', 'PRP$'): 454, ('PRP$', 'VBG'): 14, ('VBD', 'PRP'): 509, ('IN', 'PDT'): 52, ('PDT', 'DT'): 149, ('$^START^$', 'CC'): 290, ('CC', 'IN'): 291, ('NN', 'PRP'): 550, ('VBZ', 'RB'): 894, ('PRP$', 'NNP'): 54, ('RB', ','): 702, ('JJ', 'NNPS'): 31, ('NNPS', 'IN'): 67, ('VBZ', 'VBN'): 456, ('RB', 'RBR'): 62, ('RBR', 'IN'): 43, ('CC', 'MD'): 125, ('MD', 'RB'): 700, ('VB', 'JJ'): 574, ('DT', 'CD'): 248, ('NN', 'VBP'): 122, (',', 'NN'): 425, ('NN', 'NNP'): 238, ('NNP', 'MD'): 133, ('$^START^ ...
# 229671 51
